# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://jaiswalgaurav863:#GJ@9511626235!!!>@cluster0.ihevy.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[6], line 6
#       3 uri = "mongodb+srv://jaiswalgaurav863:#GJ@9511626235!!!>@cluster0.ihevy.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#       5 # Create a new client and connect to the server
# ----> 6 client = MongoClient(uri)
#       8 # Send a ping to confirm a successful connection
#       9 try:
#
# File c:\Users\Gaurav\MondoDB-Connector\venv\lib\site-packages\pymongo\synchronous\mongo_client.py:780, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     776 if timeout is not None:
#     777     timeout = common.validate_timeout_or_none_or_zero(
#     778         keyword_opts.cased_key("connecttimeoutms"), timeout
#     779     )
# --> 780 res = uri_parser.parse_uri(
#     781     entity,
#     782     port,
#     783     validate=True,
#     784     warn=True,
#     785     normalize=False,
#     786     connect_timeout=timeout,
#     787     srv_service_name=srv_service_name,
#     788     srv_max_hosts=srv_max_hosts,
#     789 )
#     790 seeds.update(res["nodelist"])
#     791 username = res["username"] or username
#
# File c:\Users\Gaurav\MondoDB-Connector\venv\lib\site-packages\pymongo\uri_parser.py:534, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     532 if "@" in host_part:
#     533     userinfo, _, hosts = host_part.rpartition("@")
# --> 534     user, passwd = parse_userinfo(userinfo)
#     535 else:
#     536     hosts = host_part
#
# File c:\Users\Gaurav\MondoDB-Connector\venv\lib\site-packages\pymongo\uri_parser.py:86, in parse_userinfo(userinfo)
#      76 """Validates the format of user information in a MongoDB URI.
#      77 Reserved characters that are gen-delimiters (":", "/", "?", "#", "[",
#      78 "]", "@") as per RFC 3986 must be escaped.
#    (...)
#      83 :param userinfo: A string of the form <username>:<password>
#      84 """
#      85 if "@" in userinfo or userinfo.count(":") > 1 or _unquoted_percent(userinfo):
# ---> 86     raise InvalidURI(
#      87         "Username and password must be escaped according to "
#      88         "RFC 3986, use urllib.parse.quote_plus"
#      89     )
#      91 user, _, passwd = userinfo.partition(":")
#      92 # No password is expected with GSSAPI authentication.
#
# InvalidURI: Username and password must be escaped according to RFC 3986, use urllib.parse.quote_plus

# %%
from typing import Any
import os
import pandas as pd
import pymongo
import json
from ensure import ensure_annotations


from typing import Any
import os
import pandas as pd
from pymongo.mongo_client import MongoClient
import json
from ensure import ensure_annotations


class mongo_operation:
    __collection=None # here i have created a private/protected variable
    __database=None
    
    def __init__(self,client_url: str, database_name: str, collection_name: str=None):
        self.client_url=client_url
        self.database_name=database_name
        self.collection_name=collection_name
       
    def create_mongo_client(self,collection=None):
        client=MongoClient(self.client_url)
        return client
    
    def create_database(self,collection=None):
        if mongo_operation.__database==None:
            client=self.create_mongo_client(collection)
            self.database=client[self.database_name]
        return self.database 
    
    def create_collection(self,collection=None):
        if mongo_operation.__collection==None:
            database=self.create_database(collection)
            self.collection=database[self.collection_name]
            mongo_operation.__collection=collection
        
        if mongo_operation.__collection!=collection:
            database=self.create_database(collection)
            self.collection=database[self.collection_name]
            mongo_operation.__collection=collection
            
        return self.collection
    
    def insert_record(self,record: dict, collection_name: str) -> Any:
        if type(record) == list:
            for data in record:
                if type(data) != dict:
                    raise TypeError("record must be in the dict")    
            collection=self.create_collection(collection_name)
            collection.insert_many(record)
        elif type(record)==dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)
    
    def bulk_insert(self,datafile,collection_name:str=None):
        self.path=datafile
        
        if self.path.endswith('.csv'):
            pd.read.csv(self.path,encoding='utf-8')
            
        elif self.path.endswith(".xlsx"):
            dataframe=pd.read_excel(self.path,encoding='utf-8')
            
        datajson=json.loads(dataframe.to_json(orient='record'))
        collection=self.create_collection()
        collection.insert_many(datajson)
